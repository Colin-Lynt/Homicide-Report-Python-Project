# %% [markdown]
# # Crime Data Analysis: Tableau Data Fix

# %% [markdown]
# ### Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# Define path
path = r'/Users/ColinLynt/Documents/CareerFoundry/01-22 Crime Data Analysis'

# %%
# Importing homicide report data
df_hr = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'Homicide_df.pkl'))

# %%
# Setting max rows/columns to see 50 rows/columns
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Data Cleaning and Preperations

# %%
# Checking Data
df_hr.head()
# Out:
#           City    State          Agency          Agentype Solved  Year  \
# 0  Autauga, AL  Alabama  Autauga County           Sheriff     No  1976
# 1  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 2  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 3  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1977
# 4  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
#
#        Month     ActionType                               Homicide  \
# 0  September  Normal update  Murder and non-negligent manslaughter
# 1    January  Normal update  Murder and non-negligent manslaughter
# 2      March  Normal update  Murder and non-negligent manslaughter
# 3      March  Normal update  Murder and non-negligent manslaughter
# 4     August  Normal update  Murder and non-negligent manslaughter
#
#                            Situation  VicAge  VicSex VicRace  \
# 0  Single victim/unknown offender(s)    30.0    Male   Black
# 1      Single victim/single offender    65.0  Female   Black
# 2   Single victim/multiple offenders    48.0    Male   White
# 3      Single victim/single offender    27.0    Male   Black
# 4      Single victim/single offender    17.0  Female   Black
#
#                  VicEthnic     OffAge   OffSex  OffRace  \
# 0  Unknown or not reported  31.138045  Unknown  Unknown
# 1  Unknown or not reported  62.000000     Male    Black
# 2  Unknown or not reported  52.000000     Male    White
# 3  Unknown or not reported  22.000000   Female    Black
# 4  Unknown or not reported  21.000000     Male    Black
#
#                  OffEthnic                           Weapon  \
# 0  Unknown or not reported            Other or type unknown
# 1  Unknown or not reported            Other or type unknown
# 2  Unknown or not reported  Handgun - pistol, revolver, etc
# 3  Unknown or not reported                          Shotgun
# 4  Unknown or not reported      Knife or cutting instrument
#
#                   Relationship                       Circumstance  VicCount  \
# 0  Relationship not determined                              Other         0
# 1                 Acquaintance  Brawl due to influence of alcohol         0
# 2                 Acquaintance                    Other arguments         0
# 3                      Husband                    Other arguments         0
# 4                 Acquaintance         Circumstances undetermined         0
#
#    OffCount
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# Assigning numerical values for months of the year
def nmonth (row):
    if row['Month'] == 'January':
        return '01'
    elif row ['Month'] == 'February':
        return '02'
    elif row ['Month'] == 'March':
        return '03'
    elif row ['Month'] == 'April':
        return '04'
    elif row ['Month'] == 'May':
        return '05'
    elif row ['Month'] == 'June':
        return '06'
    elif row ['Month'] == 'July':
        return '07'
    elif row ['Month'] == 'August':
        return '08'
    elif row ['Month'] == 'September':
        return '09'
    elif row ['Month'] == 'October':
        return '10'
    elif row ['Month'] == 'November':
        return '11'
    elif row ['Month'] == 'December':
        return '12'

# %%
# Adding new column for numerical months of the year
df_hr['NMonth'] = df_hr.apply(lambda row : nmonth(row), axis = 1)

# %%
# Changing datatype of NMonth to int64
df_hr['NMonth'] = df_hr['NMonth'].astype('int64')

# %%
# Concatenating two int64 values to make complete date 
df_hr['Date'] = df_hr['Year'].map(str) + '-' + df_hr['NMonth'].map(str)

# %%
# Checking the Date column
df_hr.head(20)
# Out:
#            City    State          Agency          Agentype Solved  Year  \
# 0   Autauga, AL  Alabama  Autauga County           Sheriff     No  1976
# 1   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 2   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 3   Autauga, AL  Alabama      Prattville  Municipal police    Yes  1977
# 4   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 5   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 6   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1978
# 7   Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1978
# 8   Autauga, AL  Alabama  Autauga County           Sheriff     No  1979
# 9   Autauga, AL  Alabama      Prattville  Municipal police    Yes  1979
# 10  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1980
# 11  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1980
# 12  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1981
# 13  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1982
# 14  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1982
# 15  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1982
# 16  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1983
# 17  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1983
# 18  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1983
# 19  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1983
#
#         Month     ActionType                               Homicide  \
# 0   September  Normal update  Murder and non-negligent manslaughter
# 1     January  Normal update  Murder and non-negligent manslaughter
# 2       March  Normal update  Murder and non-negligent manslaughter
# 3       March  Normal update  Murder and non-negligent manslaughter
# 4      August  Normal update  Murder and non-negligent manslaughter
# 5     October  Normal update  Murder and non-negligent manslaughter
# 6         May  Normal update  Murder and non-negligent manslaughter
# 7    December  Normal update  Murder and non-negligent manslaughter
# 8    February  Normal update  Murder and non-negligent manslaughter
# 9    December  Normal update  Murder and non-negligent manslaughter
# 10     August  Normal update  Murder and non-negligent manslaughter
# 11  September  Normal update  Murder and non-negligent manslaughter
# 12    January  Normal update  Murder and non-negligent manslaughter
# 13      April  Normal update  Murder and non-negligent manslaughter
# 14   December  Normal update  Murder and non-negligent manslaughter
# 15   December  Normal update  Murder and non-negligent manslaughter
# 16   February     Adjustment  Murder and non-negligent manslaughter
# 17        May     Adjustment  Murder and non-negligent manslaughter
# 18        May     Adjustment             Manslaughter by negligence
# 19       July  Normal update  Murder and non-negligent manslaughter
#
#                             Situation    VicAge  VicSex  VicRace  \
# 0   Single victim/unknown offender(s)  30.00000    Male    Black
# 1       Single victim/single offender  65.00000  Female    Black
# 2    Single victim/multiple offenders  48.00000    Male    White
# 3       Single victim/single offender  27.00000    Male    Black
# 4       Single victim/single offender  17.00000  Female    Black
# 5       Single victim/single offender  62.00000    Male    Asian
# 6    Single victim/multiple offenders  54.00000    Male    Black
# 7       Single victim/single offender  48.00000  Female    White
# 8   Single victim/unknown offender(s)  33.04365  Female  Unknown
# 9       Single victim/single offender  51.00000    Male    Black
# 10      Single victim/single offender  24.00000    Male    Black
# 11      Single victim/single offender  44.00000    Male    Black
# 12      Single victim/single offender  67.00000    Male    White
# 13      Single victim/single offender  38.00000    Male    Black
# 14      Single victim/single offender  28.00000    Male    White
# 15      Single victim/single offender  27.00000    Male    Black
# 16      Single victim/single offender  16.00000    Male    White
# 17      Single victim/single offender  56.00000    Male    White
# 18      Single victim/single offender  33.00000  Female    White
# 19      Single victim/single offender  70.00000    Male    White
#
#                   VicEthnic     OffAge   OffSex  OffRace  \
# 0   Unknown or not reported  31.138045  Unknown  Unknown
# 1   Unknown or not reported  62.000000     Male    Black
# 2   Unknown or not reported  52.000000     Male    White
# 3   Unknown or not reported  22.000000   Female    Black
# 4   Unknown or not reported  21.000000     Male    Black
# 5   Unknown or not reported  80.000000     Male    Black
# 6   Unknown or not reported  54.000000   Female    Black
# 7   Unknown or not reported  26.000000     Male    White
# 8   Unknown or not reported  31.138045  Unknown  Unknown
# 9   Unknown or not reported  24.000000   Female    Black
# 10  Unknown or not reported  26.000000     Male    Black
# 11  Unknown or not reported  68.000000     Male    White
# 12          Hispanic origin  21.000000     Male    White
# 13          Hispanic origin  28.000000     Male    Black
# 14   Not of Hispanic origin  20.000000     Male    White
# 15   Not of Hispanic origin  44.000000     Male    Black
# 16   Not of Hispanic origin  17.000000     Male    White
# 17   Not of Hispanic origin  31.138045   Female    White
# 18   Not of Hispanic origin  31.138045   Female    White
# 19  Unknown or not reported  20.000000     Male    White
#
#                   OffEthnic                            Weapon  \
# 0   Unknown or not reported             Other or type unknown
# 1   Unknown or not reported             Other or type unknown
# 2   Unknown or not reported   Handgun - pistol, revolver, etc
# 3   Unknown or not reported                           Shotgun
# 4   Unknown or not reported       Knife or cutting instrument
# 5   Unknown or not reported                           Shotgun
# 6   Unknown or not reported       Knife or cutting instrument
# 7   Unknown or not reported  Blunt object - hammer, club, etc
# 8   Unknown or not reported             Other or type unknown
# 9   Unknown or not reported       Knife or cutting instrument
# 10  Unknown or not reported                             Rifle
# 11  Unknown or not reported   Handgun - pistol, revolver, etc
# 12          Hispanic origin       Knife or cutting instrument
# 13  Unknown or not reported                             Rifle
# 14   Not of Hispanic origin   Handgun - pistol, revolver, etc
# 15   Not of Hispanic origin   Handgun - pistol, revolver, etc
# 16   Not of Hispanic origin       Knife or cutting instrument
# 17   Not of Hispanic origin   Handgun - pistol, revolver, etc
# 18   Not of Hispanic origin   Handgun - pistol, revolver, etc
# 19  Unknown or not reported             Other or type unknown
#
#                    Relationship                       Circumstance  VicCount  \
# 0   Relationship not determined                              Other         0
# 1                  Acquaintance  Brawl due to influence of alcohol         0
# 2                  Acquaintance                    Other arguments         0
# 3                       Husband                    Other arguments         0
# 4                  Acquaintance         Circumstances undetermined         0
# 5                      Stranger                            Robbery         0
# 6                       Husband         Circumstances undetermined         0
# 7                  Acquaintance                              Other         0
# 8   Relationship not determined         Circumstances undetermined         0
# 9            Common-law husband                    Other arguments         0
# 10                 Acquaintance                    Other arguments         0
# 11                 Acquaintance                    Other arguments         0
# 12                 Acquaintance                              Other         0
# 13                       In-law                    Other arguments         0
# 14                       Friend                    Other arguments         0
# 15                          Son                    Other arguments         0
# 16                 Acquaintance                    Other arguments         0
# 17                       In-law                    Other arguments         0
# 18                     Daughter    Other negligent handling of gun         0
# 19                       Friend                              Other         0
#
#     OffCount  NMonth     Date
# 0          0       9   1976-9
# 1          0       1   1977-1
# 2          1       3   1977-3
# 3          0       3   1977-3
# 4          0       8   1977-8
# 5          0      10  1977-10
# 6          2       5   1978-5
# 7          0      12  1978-12
# 8          0       2   1979-2
# 9          0      12  1979-12
# 10         0       8   1980-8
# 11         0       9   1980-9
# 12         0       1   1981-1
# 13         0       4   1982-4
# 14         0      12  1982-12
# 15         0      12  1982-12
# 16         0       2   1983-2
# 17         0       5   1983-5
# 18         0       5   1983-5
# 19         0       7   1983-7

# %%
# Dropping NMonth
df_hr = df_hr.drop(columns = ['NMonth'])

# %%
# Checking for dropped column
df_hr.head()
# Out:
#           City    State          Agency          Agentype Solved  Year  \
# 0  Autauga, AL  Alabama  Autauga County           Sheriff     No  1976
# 1  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 2  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 3  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1977
# 4  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
#
#        Month     ActionType                               Homicide  \
# 0  September  Normal update  Murder and non-negligent manslaughter
# 1    January  Normal update  Murder and non-negligent manslaughter
# 2      March  Normal update  Murder and non-negligent manslaughter
# 3      March  Normal update  Murder and non-negligent manslaughter
# 4     August  Normal update  Murder and non-negligent manslaughter
#
#                            Situation  VicAge  VicSex VicRace  \
# 0  Single victim/unknown offender(s)    30.0    Male   Black
# 1      Single victim/single offender    65.0  Female   Black
# 2   Single victim/multiple offenders    48.0    Male   White
# 3      Single victim/single offender    27.0    Male   Black
# 4      Single victim/single offender    17.0  Female   Black
#
#                  VicEthnic     OffAge   OffSex  OffRace  \
# 0  Unknown or not reported  31.138045  Unknown  Unknown
# 1  Unknown or not reported  62.000000     Male    Black
# 2  Unknown or not reported  52.000000     Male    White
# 3  Unknown or not reported  22.000000   Female    Black
# 4  Unknown or not reported  21.000000     Male    Black
#
#                  OffEthnic                           Weapon  \
# 0  Unknown or not reported            Other or type unknown
# 1  Unknown or not reported            Other or type unknown
# 2  Unknown or not reported  Handgun - pistol, revolver, etc
# 3  Unknown or not reported                          Shotgun
# 4  Unknown or not reported      Knife or cutting instrument
#
#                   Relationship                       Circumstance  VicCount  \
# 0  Relationship not determined                              Other         0
# 1                 Acquaintance  Brawl due to influence of alcohol         0
# 2                 Acquaintance                    Other arguments         0
# 3                      Husband                    Other arguments         0
# 4                 Acquaintance         Circumstances undetermined         0
#
#    OffCount    Date
# 0         0  1976-9
# 1         0  1977-1
# 2         1  1977-3
# 3         0  1977-3
# 4         0  1977-8

# %%
# Assigning numerical value to VicSex - 0 is Unknown / 1 is Male / 2 is Female
def categories_3 (row):
    if row['VicSex'] == 'Unknown':
        return '0'
    elif row ['VicSex'] == 'Male':
        return '1'
    elif row ['VicSex'] == 'Female':
        return '2'

# %%
# Adding new column NVicSex - Gives numerical value to VicSex column
df_hr['NVicSex'] = df_hr.apply(lambda row : categories_3(row), axis = 1)

# %%
# Assigning numerical value to OffSex - 0 is Unknown / 1 is Male / 2 is Female
def categories_4 (row):
    if row['OffSex'] == 'Unknown':
        return '0'
    elif row ['OffSex'] == 'Male':
        return '1'
    elif row ['OffSex'] == 'Female':
        return '2'

# %%
# Adding new column NOffSex - Gives numerical value to OffSex column
df_hr['NOffSex'] = df_hr.apply(lambda row : categories_4(row), axis = 1)

# %%
# Assigning numerical value to VicRace
def categories_5 (row):
    if row['VicRace'] == 'Unknown':
        return '0'
    elif row ['VicRace'] == 'White':
        return '1'
    elif row ['VicRace'] == 'Black':
        return '2'
    elif row ['VicRace'] == 'Asian':
        return '3'
    elif row ['VicRace'] == 'American Indian or Alaskan Native':
        return '4'
    elif row ['VicRace'] == 'Native Hawaiian or Pacific Islander':
        return '5'

# %%
# Adding new column NVicRace - Gives numerical value to VicRace column
df_hr['NVicRace'] = df_hr.apply(lambda row : categories_5(row), axis = 1)

# %%
# Assigning numerical value to OffRace
def categories_6 (row):
    if row['OffRace'] == 'Unknown':
        return '0'
    elif row ['OffRace'] == 'White':
        return '1'
    elif row ['OffRace'] == 'Black':
        return '2'
    elif row ['OffRace'] == 'Asian':
        return '3'
    elif row ['OffRace'] == 'American Indian or Alaskan Native':
        return '4'
    elif row ['OffRace'] == 'Native Hawaiian or Pacific Islander':
        return '5'

# %%
# Adding new column NOffRace - Gives numerical value to OffRace column
df_hr['NOffRace'] = df_hr.apply(lambda row : categories_6(row), axis = 1)

# %%
# Assigning numerical value to closeness of victim and offender
def closeness (row):
    if row['Relationship'] == 'Stranger':
        return '1'
    elif row ['Relationship'] == 'Acquaintance':
        return '2'
    elif row ['Relationship'] == 'Other - known to victim':
        return '2'
    elif row ['Relationship'] == 'Wife':
        return '4'
    elif row ['Relationship'] == 'Friend':
        return '3'
    elif row ['Relationship'] == 'Girlfriend':
        return '3'
    elif row ['Relationship'] == 'Son':
        return '4'
    elif row ['Relationship'] == 'Other family':
        return '4'
    elif row ['Relationship'] == 'Husband':
        return '4'
    elif row ['Relationship'] == 'Boyfriend':
        return '3'
    elif row ['Relationship'] == 'Daughter':
        return '4'
    elif row ['Relationship'] == 'Neighbor':
        return '2'
    elif row ['Relationship'] == 'Brother':
        return '4'
    elif row ['Relationship'] == 'Father':
        return '4'
    elif row ['Relationship'] == 'Mother':
        return '4'
    elif row ['Relationship'] == 'In-law':
        return '4'
    elif row ['Relationship'] == 'Common-law wife':
        return '3'
    elif row ['Relationship'] == 'Common-law husband':
        return '3'
    elif row ['Relationship'] == 'Ex-wife':
        return '3'
    elif row ['Relationship'] == 'Stepfather':
        return '4'
    elif row ['Relationship'] == 'Sister':
        return '4'
    elif row ['Relationship'] == 'Homosexual relationship':
        return '3'
    elif row ['Relationship'] == 'Stepson':
        return '4'
    elif row ['Relationship'] == 'Ex-husband':
        return '3'
    elif row ['Relationship'] == 'Stepdaughter':
        return '4'
    elif row ['Relationship'] == 'Employer':
        return '2'
    elif row ['Relationship'] == 'Employee':
        return '2'
    elif row ['Relationship'] == 'Stepmother':
        return '4'

# %%
# Adding new column Closeness_Rating - Gives ranked value to Relationships
df_hr['Closeness_Rating'] = df_hr.apply(lambda row : closeness(row), axis = 1)

# %%
# Assigning numerical value to Weapon
def categories_7 (row):
    if row['Weapon'] == 'Handgun - pistol, revolver, etc':
        return '1'
    elif row ['Weapon'] == 'Knife or cutting instrument':
        return '2'
    elif row ['Weapon'] == 'Firearm, type not stated':
        return '3'
    elif row ['Weapon'] == 'Personal weapons, includes beating':
        return '4'
    elif row ['Weapon'] == 'Other or type unknown':
        return '5'
    elif row ['Weapon'] == 'Shotgun':
        return '6'
    elif row ['Weapon'] == 'Blunt object - hammer, club, etc':
        return '7'
    elif row ['Weapon'] == 'Rifle':
        return '8'
    elif row ['Weapon'] == 'Strangulation - hanging':
        return '9'
    elif row ['Weapon'] == 'Fire':
        return '10'
    elif row ['Weapon'] == 'Asphyxiation - includes death by gas':
        return '11'
    elif row ['Weapon'] == 'Other gun':
        return '12'
    elif row ['Weapon'] == 'Narcotics or drugs, sleeping pills':
        return '13'
    elif row ['Weapon'] == 'Drowning':
        return '14'
    elif row ['Weapon'] == 'Poison - does not include gas':
        return '15'
    elif row ['Weapon'] == 'Explosives':
        return '16'
    elif row ['Weapon'] == 'Pushed or thrown out window':
        return '17'

# %%
# Adding new column NWeapon - Gives numerical value to Weapon column
df_hr['NWeapon'] = df_hr.apply(lambda row : categories_7(row), axis = 1)

# %%
# Assigning numerical value to yes or no in Solved column - No is 0 / Yes is 1
def categories (row):
    if row['Solved'] == 'No':
        return '0'
    elif row ['Solved'] == 'Yes':
        return '1'

# %%
# Adding new column NSolved - Gives numerical value to Solved column
df_hr['NSolved'] = df_hr.apply(lambda row : categories(row), axis = 1)

# %%
# Changing NSolved to int64
df_hr['NSolved'] = df_hr['NSolved'].astype('int64')

# %%
# Changing NVicSex to int64
df_hr['NVicSex'] = df_hr['NVicSex'].astype('int64')

# %%
# Changing NOffSex to int64
df_hr['NOffSex'] = df_hr['NOffSex'].astype('int64')

# %%
# Changing NVicRace to int64
df_hr['NVicRace'] = df_hr['NVicRace'].astype('int64')

# %%
# Changing NOffRace to int64
df_hr['NOffRace'] = df_hr['NOffRace'].astype('int64')

# %%
# Changing NWeapon to int64
df_hr['NWeapon'] = df_hr['NWeapon'].astype('int64')

# %%
# Checking changes
df_hr.head()
# Out:
#           City    State          Agency          Agentype Solved  Year  \
# 0  Autauga, AL  Alabama  Autauga County           Sheriff     No  1976
# 1  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 2  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 3  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1977
# 4  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
#
#        Month     ActionType                               Homicide  \
# 0  September  Normal update  Murder and non-negligent manslaughter
# 1    January  Normal update  Murder and non-negligent manslaughter
# 2      March  Normal update  Murder and non-negligent manslaughter
# 3      March  Normal update  Murder and non-negligent manslaughter
# 4     August  Normal update  Murder and non-negligent manslaughter
#
#                            Situation  VicAge  VicSex VicRace  \
# 0  Single victim/unknown offender(s)    30.0    Male   Black
# 1      Single victim/single offender    65.0  Female   Black
# 2   Single victim/multiple offenders    48.0    Male   White
# 3      Single victim/single offender    27.0    Male   Black
# 4      Single victim/single offender    17.0  Female   Black
#
#                  VicEthnic     OffAge   OffSex  OffRace  \
# 0  Unknown or not reported  31.138045  Unknown  Unknown
# 1  Unknown or not reported  62.000000     Male    Black
# 2  Unknown or not reported  52.000000     Male    White
# 3  Unknown or not reported  22.000000   Female    Black
# 4  Unknown or not reported  21.000000     Male    Black
#
#                  OffEthnic                           Weapon  \
# 0  Unknown or not reported            Other or type unknown
# 1  Unknown or not reported            Other or type unknown
# 2  Unknown or not reported  Handgun - pistol, revolver, etc
# 3  Unknown or not reported                          Shotgun
# 4  Unknown or not reported      Knife or cutting instrument
#
#                   Relationship                       Circumstance  VicCount  \
# 0  Relationship not determined                              Other         0
# 1                 Acquaintance  Brawl due to influence of alcohol         0
# 2                 Acquaintance                    Other arguments         0
# 3                      Husband                    Other arguments         0
# 4                 Acquaintance         Circumstances undetermined         0
#
#    OffCount    Date  NVicSex  NOffSex  NVicRace  NOffRace Closeness_Rating  \
# 0         0  1976-9        1        0         2         0             None
# 1         0  1977-1        2        1         2         2                2
# 2         1  1977-3        1        1         1         1                2
# 3         0  1977-3        1        2         2         2                4
# 4         0  1977-8        2        1         2         2                2
#
#    NWeapon  NSolved
# 0        5        0
# 1        5        1
# 2        1        1
# 3        6        1
# 4        2        1

# %%
# Dropping Relationship Undetermined as it does not apply to mapping
df_hr.drop(df_hr.loc[df_hr['Relationship'] == 'Relationship not determined'].index, inplace = True)

# %%
# Checking the shape of df after drop
df_hr.shape
# Out:
# (504551, 31)

# %%
# Dropping District of Columbia as it's not a state
df_hr.drop(df_hr.loc[df_hr['State'] == 'District of Columbia'].index, inplace = True)

# %%
# Checking what PAPSP8 is
df_hr.loc[df_hr['State'] == 'PAPSP8']
# Out:
#                 City   State                  Agency          Agentype Solved  \
# 661383  Somerset, PA  PAPSP8  State Police, Somerset  Primary state LE    Yes
#
#         Year  Month     ActionType                    Homicide  \
# 661383  2020  March  Normal update  Manslaughter by negligence
#
#                             Situation  VicAge  VicSex VicRace  \
# 661383  Single victim/single offender    12.0  Female   White
#
#                      VicEthnic  OffAge  OffSex OffRace  \
# 661383  Not of Hispanic origin    52.0  Female   White
#
#                      OffEthnic                              Weapon  \
# 661383  Not of Hispanic origin  Narcotics or drugs, sleeping pills
#
#         Relationship                          Circumstance  VicCount  \
# 661383  Other family  All other manslaughter by negligence         0
#
#         OffCount    Date  NVicSex  NOffSex  NVicRace  NOffRace  \
# 661383         0  2020-3        2        2         1         1
#
#        Closeness_Rating  NWeapon  NSolved
# 661383                4       13        1

# %%
# Changing PAPSP8 to Pennsylvania
df_hr.at[661383,'State'] = 'Pennsylvania'

# %%
# Changing Rhodes Island to Rhode Island
df_hr.replace('Rhodes Island', 'Rhode Island', inplace = True)

# %%
# Checking for Rhode Island
df_hr.loc[df_hr['State'] == 'Rhode Island']
# Out:
#                   City         State           Agency          Agentype  \
# 662901     Bristol, RI  Rhode Island           Warren  Municipal police
# 662903     Bristol, RI  Rhode Island       Barrington  Municipal police
# 662904     Bristol, RI  Rhode Island       Barrington  Municipal police
# 662905     Bristol, RI  Rhode Island       Barrington  Municipal police
# 662906     Bristol, RI  Rhode Island       Barrington  Municipal police
# ...                ...           ...              ...               ...
# 664388  Washington, RI  Rhode Island     Narragansett  Municipal police
# 664390  Washington, RI  Rhode Island  North Kingstown  Municipal police
# 664391  Washington, RI  Rhode Island         Westerly  Municipal police
# 664392  Washington, RI  Rhode Island         Westerly  Municipal police
# 664393  Washington, RI  Rhode Island         Westerly  Municipal police
#
#        Solved  Year     Month     ActionType  \
# 662901    Yes  1977     April  Normal update
# 662903    Yes  1985       May  Normal update
# 662904    Yes  1991  November  Normal update
# 662905    Yes  1991  November  Normal update
# 662906    Yes  1991  November  Normal update
# ...       ...   ...       ...            ...
# 664388    Yes  2013       May  Normal update
# 664390    Yes  2017      June  Normal update
# 664391    Yes  2018   January  Normal update
# 664392    Yes  2019  December  Normal update
# 664393    Yes  2020   January  Normal update
#
#                                      Homicide  \
# 662901  Murder and non-negligent manslaughter
# 662903  Murder and non-negligent manslaughter
# 662904  Murder and non-negligent manslaughter
# 662905  Murder and non-negligent manslaughter
# 662906  Murder and non-negligent manslaughter
# ...                                       ...
# 664388  Murder and non-negligent manslaughter
# 664390  Murder and non-negligent manslaughter
# 664391  Murder and non-negligent manslaughter
# 664392  Murder and non-negligent manslaughter
# 664393  Murder and non-negligent manslaughter
#
#                                Situation  VicAge  VicSex VicRace  \
# 662901     Single victim/single offender    41.0    Male   White
# 662903     Single victim/single offender    38.0  Female   White
# 662904  Multiple victims/single offender    53.0    Male   White
# 662905  Multiple victims/single offender    46.0  Female   White
# 662906  Multiple victims/single offender     8.0  Female   White
# ...                                  ...     ...     ...     ...
# 664388  Single victim/multiple offenders    65.0  Female   White
# 664390     Single victim/single offender    69.0  Female   White
# 664391     Single victim/single offender    50.0    Male   White
# 664392     Single victim/single offender    47.0  Female   White
# 664393     Single victim/single offender    28.0    Male   Black
#
#                       VicEthnic  OffAge  OffSex  \
# 662901  Unknown or not reported    39.0    Male
# 662903   Not of Hispanic origin    33.0  Female
# 662904  Unknown or not reported    42.0    Male
# 662905  Unknown or not reported    42.0    Male
# 662906  Unknown or not reported    42.0    Male
# ...                         ...     ...     ...
# 664388  Unknown or not reported    45.0    Male
# 664390   Not of Hispanic origin    38.0    Male
# 664391   Not of Hispanic origin    50.0    Male
# 664392   Not of Hispanic origin    66.0    Male
# 664393   Not of Hispanic origin    31.0    Male
#
#                                   OffRace                OffEthnic  \
# 662901                              White  Unknown or not reported
# 662903                              White   Not of Hispanic origin
# 662904                              White  Unknown or not reported
# 662905                              White  Unknown or not reported
# 662906                              White  Unknown or not reported
# ...                                   ...                      ...
# 664388                              White  Unknown or not reported
# 664390                              White  Unknown or not reported
# 664391                              White  Unknown or not reported
# 664392                              White  Unknown or not reported
# 664393  American Indian or Alaskan Native  Unknown or not reported
#
#                                  Weapon             Relationship  \
# 662901  Handgun - pistol, revolver, etc             Acquaintance
# 662903  Handgun - pistol, revolver, etc                 Stranger
# 662904      Knife or cutting instrument             Acquaintance
# 662905      Knife or cutting instrument             Acquaintance
# 662906      Knife or cutting instrument             Acquaintance
# ...                                 ...                      ...
# 664388            Other or type unknown                   Mother
# 664390            Other or type unknown                 Stranger
# 664391      Knife or cutting instrument             Acquaintance
# 664392  Handgun - pistol, revolver, etc  Other - known to victim
# 664393  Handgun - pistol, revolver, etc  Other - known to victim
#
#                       Circumstance  VicCount  OffCount     Date  NVicSex  \
# 662901  Circumstances undetermined         0         0   1977-4        1
# 662903  Circumstances undetermined         0         0   1985-5        2
# 662904       Other - not specified         2         0  1991-11        1
# 662905       Other - not specified         2         0  1991-11        2
# 662906       Other - not specified         2         0  1991-11        2
# ...                            ...       ...       ...      ...      ...
# 664388  Circumstances undetermined         0         1   2013-5        2
# 664390                       Other         0         0   2017-6        2
# 664391             Other arguments         0         0   2018-1        1
# 664392  Circumstances undetermined         0         0  2019-12        2
# 664393             Other arguments         0         0   2020-1        1
#
#         NOffSex  NVicRace  NOffRace Closeness_Rating  NWeapon  NSolved
# 662901        1         1         1                2        1        1
# 662903        2         1         1                1        1        1
# 662904        1         1         1                2        2        1
# 662905        1         1         1                2        2        1
# 662906        1         1         1                2        2        1
# ...         ...       ...       ...              ...      ...      ...
# 664388        1         1         1                4        5        1
# 664390        1         1         1                1        5        1
# 664391        1         1         1                2        2        1
# 664392        1         1         1                2        1        1
# 664393        1         2         4                2        1        1
#
# [917 rows x 31 columns]

# %%
# Checking value counts in Closeness_Rating
df_hr['Closeness_Rating'].value_counts(dropna = False)
# Out:
# 2    205235
# 1    119778
# 4    107261
# 3     69809
# Name: Closeness_Rating, dtype: int64

# %%
# Checking data
df_hr.head()
# Out:
#           City    State          Agency          Agentype Solved  Year  \
# 1  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 2  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 3  Autauga, AL  Alabama      Prattville  Municipal police    Yes  1977
# 4  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
# 5  Autauga, AL  Alabama  Autauga County           Sheriff    Yes  1977
#
#      Month     ActionType                               Homicide  \
# 1  January  Normal update  Murder and non-negligent manslaughter
# 2    March  Normal update  Murder and non-negligent manslaughter
# 3    March  Normal update  Murder and non-negligent manslaughter
# 4   August  Normal update  Murder and non-negligent manslaughter
# 5  October  Normal update  Murder and non-negligent manslaughter
#
#                           Situation  VicAge  VicSex VicRace  \
# 1     Single victim/single offender    65.0  Female   Black
# 2  Single victim/multiple offenders    48.0    Male   White
# 3     Single victim/single offender    27.0    Male   Black
# 4     Single victim/single offender    17.0  Female   Black
# 5     Single victim/single offender    62.0    Male   Asian
#
#                  VicEthnic  OffAge  OffSex OffRace                OffEthnic  \
# 1  Unknown or not reported    62.0    Male   Black  Unknown or not reported
# 2  Unknown or not reported    52.0    Male   White  Unknown or not reported
# 3  Unknown or not reported    22.0  Female   Black  Unknown or not reported
# 4  Unknown or not reported    21.0    Male   Black  Unknown or not reported
# 5  Unknown or not reported    80.0    Male   Black  Unknown or not reported
#
#                             Weapon  Relationship  \
# 1            Other or type unknown  Acquaintance
# 2  Handgun - pistol, revolver, etc  Acquaintance
# 3                          Shotgun       Husband
# 4      Knife or cutting instrument  Acquaintance
# 5                          Shotgun      Stranger
#
#                         Circumstance  VicCount  OffCount     Date  NVicSex  \
# 1  Brawl due to influence of alcohol         0         0   1977-1        2
# 2                    Other arguments         0         1   1977-3        1
# 3                    Other arguments         0         0   1977-3        1
# 4         Circumstances undetermined         0         0   1977-8        2
# 5                            Robbery         0         0  1977-10        1
#
#    NOffSex  NVicRace  NOffRace Closeness_Rating  NWeapon  NSolved
# 1        1         2         2                2        5        1
# 2        1         1         1                2        1        1
# 3        2         2         2                4        6        1
# 4        1         2         2                2        2        1
# 5        1         3         2                1        6        1

# %%
# Exporting df_hr to CSV
df_hr.to_csv(os.path.join(path, '02 Data', 'Prepared data', 'Homicide_Tableau_df.csv'))

# %%
df_hr.shape
# Out:
# (502083, 31)

# %%
# Creating a sub-df for state names
StateV = df_hr.State.unique()
StateV
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)
